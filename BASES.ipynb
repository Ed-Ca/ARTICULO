# %%
## Leo el primer archivo que aparece sin necesidad de ordenar
from pyspark.sql import SparkSession
import os

# Crear sesión de Spark
spark = SparkSession.builder.appName("LeerTXT").master("local[*]").getOrCreate()

# %%
df_20001 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20001.txt', header=True, inferSchema=True, sep="|")
df_20002 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20002.txt', header=True, inferSchema=True, sep="|")
df_20011 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20011.txt', header=True, inferSchema=True, sep="|")
df_20012 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20012.txt', header=True, inferSchema=True, sep="|")
df_20021 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20021.txt', header=True, inferSchema=True, sep="|")
df_20022 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20022.txt', header=True, inferSchema=True, sep="|")
df_20032 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20032.txt', header=True, inferSchema=True, sep="|")
df_20041 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20041.txt', header=True, inferSchema=True, sep="|")
df_20042 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20042.txt', header=True, inferSchema=True, sep="|")
df_20051 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20051.txt', header=True, inferSchema=True, sep="|")
df_20052 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20052.txt', header=True, inferSchema=True, sep="|")
df_20061 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20061.txt', header=True, inferSchema=True, sep="¬")
df_20062 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20062.txt', header=True, inferSchema=True, sep="¬")
df_20071 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20071.txt', header=True, inferSchema=True, sep="¬")
df_20072 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20072.txt', header=True, inferSchema=True, sep="¬")
df_20081 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20081.txt', header=True, inferSchema=True, sep="¬")
df_20082 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20082.txt', header=True, inferSchema=True, sep="¬")
df_20091 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20091.txt', header=True, inferSchema=True, sep="¬")
df_20092 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20092.txt', header=True, inferSchema=True, sep="¬")
df_20101 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20101.txt', header=True, inferSchema=True, sep="¬")
df_20102 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20102.txt', header=True, inferSchema=True, sep="¬")
df_20111 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20111.txt', header=True, inferSchema=True, sep="¬")
df_20112 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20112.txt', header=True, inferSchema=True, sep="¬")
df_20121 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20121.txt', header=True, inferSchema=True, sep="¬")
df_20122 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20122.txt', header=True, inferSchema=True, sep="¬")
df_20131 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20131.txt', header=True, inferSchema=True, sep="¬")
df_20132 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20132.txt', header=True, inferSchema=True, sep="¬")
df_20141 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20141.txt', header=True, inferSchema=True, sep="¬")
df_20142 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20142.txt', header=True, inferSchema=True, sep="¬")
df_20151 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20151.txt', header=True, inferSchema=True, sep="¬")
df_20152 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20152.txt', header=True, inferSchema=True, sep="¬")

df_20161 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20161.txt', header=True, inferSchema=True, sep="¬")
df_20162 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20162.txt', header=True, inferSchema=True, sep="¬")
df_20171 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20171.txt', header=True, inferSchema=True, sep="¬")
df_20172 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20172.txt', header=True, inferSchema=True, sep="¬")
df_20181 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20181.txt', header=True, inferSchema=True, sep="¬")
df_20182 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20182.txt', header=True, inferSchema=True, sep="¬")

df_20191_ = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20191_.txt', header=True, inferSchema=True, sep="|")
df_20192 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20192.txt', header=True, inferSchema=True, sep="¬")
df_20201 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20201.txt', header=True, inferSchema=True, sep="¬")
df_20202 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20202.txt', header=True, inferSchema=True, sep="¬")
df_20211 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20211.txt', header=True, inferSchema=True, sep="¬")
df_20212 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20212.txt', header=True, inferSchema=True, sep="¬")

df_20221 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20221.txt', header=True, inferSchema=True, sep="¬")
df_20222 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20222.txt', header=True, inferSchema=True, sep="¬")
df_20231 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20231.txt', header=True, inferSchema=True, sep="¬")
df_20232 = spark.read.csv('BASES_ED/SABER11ENUNA/SB11_20232.txt', header=True, inferSchema=True, sep="¬")

# %%
df_20001 =  df_20001.toDF(*[col.upper() for col in df_20001.columns]) 
df_20002 =  df_20002.toDF(*[col.upper() for col in df_20002.columns]) 
df_20011 =  df_20011.toDF(*[col.upper() for col in df_20011.columns]) 
df_20012 =  df_20012.toDF(*[col.upper() for col in df_20012.columns]) 
df_20021 =  df_20021.toDF(*[col.upper() for col in df_20021.columns]) 
df_20022 =  df_20022.toDF(*[col.upper() for col in df_20022.columns]) 
df_20032 =  df_20032.toDF(*[col.upper() for col in df_20032.columns]) 
df_20041 =  df_20041.toDF(*[col.upper() for col in df_20041.columns]) 
df_20042 =  df_20042.toDF(*[col.upper() for col in df_20042.columns]) 
df_20051 =  df_20051.toDF(*[col.upper() for col in df_20051.columns]) 
df_20052 =  df_20052.toDF(*[col.upper() for col in df_20052.columns]) 
df_20061 =  df_20061.toDF(*[col.upper() for col in df_20061.columns]) 
df_20062 =  df_20062.toDF(*[col.upper() for col in df_20062.columns]) 
df_20071 =  df_20071.toDF(*[col.upper() for col in df_20071.columns]) 
df_20072 =  df_20072.toDF(*[col.upper() for col in df_20072.columns]) 
df_20081 =  df_20081.toDF(*[col.upper() for col in df_20081.columns]) 
df_20082 =  df_20082.toDF(*[col.upper() for col in df_20082.columns]) 
df_20091 =  df_20091.toDF(*[col.upper() for col in df_20091.columns]) 
df_20092 =  df_20092.toDF(*[col.upper() for col in df_20092.columns]) 
df_20101 =  df_20101.toDF(*[col.upper() for col in df_20101.columns]) 
df_20102 =  df_20102.toDF(*[col.upper() for col in df_20102.columns]) 
df_20111 =  df_20111.toDF(*[col.upper() for col in df_20111.columns]) 
df_20112 =  df_20112.toDF(*[col.upper() for col in df_20112.columns]) 
df_20121 =  df_20121.toDF(*[col.upper() for col in df_20121.columns])
df_20122 =  df_20122.toDF(*[col.upper() for col in df_20122.columns]) 
df_20131 =  df_20131.toDF(*[col.upper() for col in df_20131.columns])
df_20132 =  df_20132.toDF(*[col.upper() for col in df_20132.columns]) 
df_20141 =  df_20141.toDF(*[col.upper() for col in df_20141.columns])
df_20142 =  df_20142.toDF(*[col.upper() for col in df_20142.columns]) 
df_20151 =  df_20151.toDF(*[col.upper() for col in df_20151.columns]) 
df_20152 =  df_20152.toDF(*[col.upper() for col in df_20152.columns]) 

df_20161 =  df_20161.toDF(*[col.upper() for col in df_20161.columns]) 
df_20162 =  df_20162.toDF(*[col.upper() for col in df_20162.columns]) 
df_20171 =  df_20171.toDF(*[col.upper() for col in df_20171.columns]) 
df_20172 =  df_20172.toDF(*[col.upper() for col in df_20172.columns]) 
df_20181 =  df_20181.toDF(*[col.upper() for col in df_20181.columns]) 
df_20182 =  df_20182.toDF(*[col.upper() for col in df_20182.columns]) 
df_20192 =  df_20192.toDF(*[col.upper() for col in df_20192.columns]) 

df_20191_ =  df_20191_.toDF(*[col.upper() for col in df_20191_.columns]) 
df_20201 =  df_20201.toDF(*[col.upper() for col in df_20201.columns]) 
df_20202 =  df_20202.toDF(*[col.upper() for col in df_20202.columns]) 
df_20211 =  df_20211.toDF(*[col.upper() for col in df_20211.columns]) 
df_20212 =  df_20212.toDF(*[col.upper() for col in df_20212.columns])

df_20221 =  df_20221.toDF(*[col.upper() for col in df_20221.columns]) 
df_20222 =  df_20222.toDF(*[col.upper() for col in df_20222.columns]) 
df_20231 =  df_20231.toDF(*[col.upper() for col in df_20231.columns]) 
df_20232 =  df_20232.toDF(*[col.upper() for col in df_20232.columns])

# %%
# columnas_eliminar_df_20001 = ["COD_IDIOMA","COD_INTERDISCIPLINAR","COLE_DEPTO_UBICACION","COLE_MCPIO_UBICACION","ESTU_ACT_PROX_ANNO",
#                               "ESTU_CARRDESEADA_COD","ESTU_DEPTO_PRESENTACION","ESTU_LIMITA_INVIDENTE","ESTU_LIMITA_MOTRIZ",
#                               "ESTU_LIMITA_SORDOINTERPRETE","ESTU_LIMITA_SORDONOINTERPRETE","ESTU_MCPIO_PRESENTACION","FAMI_APORTANTES",
#                               "FAMI_DEUDA_VIVIENDA","FAMI_INGRESO_FMILIAR_MENSUAL","FAMI_LEE_ESCRIBE_MADRE","FAMI_LEE_ESCRIBE_PADRE",
#                               "FAMI_NUM_HERMANOS","FAMI_NUM_HERMANOS_EDUSUPERIOR","FAMI_OCUPA_MADRE","FAMI_OCUPA_PADRE",
#                               "FAMI_POSICION_HERMANOS","FAMI_SOST_PERSONAL","FAMI_VIVIENDA_PROPIA","IND_ANNO_TERMINO_BACHILLERATO",
#                               "PUNT_GEOGRAFIA","PUNT_HISTORIA","PUNT_IDIOMA",]
# df_20001 = df_20001.drop(*columnas_eliminar_df_20001)


# columnas_eliminar_df_20011 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_ACT_PROX_ANNO", 
#                               "ESTU_CARRDESEADA_COD", "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_APORTANTES", 
#                               "FAMI_DEUDA_VIVIENDA", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_NUM_HERMANOS_EDUSUPERIOR", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", 
#                               "FAMI_POSICION_HERMANOS", "FAMI_SOST_PERSONAL", "FAMI_VIVIENDA_PROPIA", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",]

# df_20011 = df_20011.drop(*columnas_eliminar_df_20011)


# columnas_eliminar_df_20012 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_ACT_PROX_ANNO", 
#                               "ESTU_CARRDESEADA_COD", "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_APORTANTES", 
#                               "FAMI_DEUDA_VIVIENDA", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_NUM_HERMANOS_EDUSUPERIOR", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", 
#                               "FAMI_POSICION_HERMANOS", "FAMI_SOST_PERSONAL", "FAMI_VIVIENDA_PROPIA", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",]

# df_20012 = df_20012.drop(*columnas_eliminar_df_20012)



# columnas_eliminar_df_20021 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_ACT_PROX_ANNO", 
#                               "ESTU_CARRDESEADA_COD", "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_APORTANTES", 
#                               "FAMI_DEUDA_VIVIENDA", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_NUM_HERMANOS_EDUSUPERIOR", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", 
#                               "FAMI_POSICION_HERMANOS", "FAMI_SOST_PERSONAL", "FAMI_VIVIENDA_PROPIA", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",]

# df_20021 = df_20021.drop(*columnas_eliminar_df_20021)


# columnas_eliminar_df_20022 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_ACT_PROX_ANNO", 
#                               "ESTU_CARRDESEADA_COD", "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_APORTANTES", 
#                               "FAMI_DEUDA_VIVIENDA", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_NUM_HERMANOS_EDUSUPERIOR", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", 
#                               "FAMI_POSICION_HERMANOS", "FAMI_SOST_PERSONAL", "FAMI_VIVIENDA_PROPIA", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",
# ]
# df_20022 = df_20022.drop(*columnas_eliminar_df_20022)


# columnas_eliminar_df_20032 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_ACT_PROX_ANNO", 
#                               "ESTU_CARRDESEADA_COD", "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_APORTANTES", 
#                               "FAMI_DEUDA_VIVIENDA", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_NUM_HERMANOS_EDUSUPERIOR", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", 
#                               "FAMI_POSICION_HERMANOS", "FAMI_SOST_PERSONAL", "FAMI_VIVIENDA_PROPIA", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",
# ]
# df_20032 = df_20032.drop(*columnas_eliminar_df_20032)


# columnas_eliminar_df_20041 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_ACT_PROX_ANNO", 
#                               "ESTU_CARRDESEADA_COD", "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_APORTANTES", 
#                               "FAMI_DEUDA_VIVIENDA", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_NUM_HERMANOS_EDUSUPERIOR", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", 
#                               "FAMI_POSICION_HERMANOS", "FAMI_SOST_PERSONAL", "FAMI_VIVIENDA_PROPIA", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",
# ]
# df_20041 = df_20041.drop(*columnas_eliminar_df_20041)


# columnas_eliminar_df_20042 = ["COD_IDIOMA", "COD_INTERDISCIPLINAR", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "ESTU_CARRDESEADA_COD", 
#                               "ESTU_DEPTO_PRESENTACION", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", "ESTU_LIMITA_SORDOINTERPRETE", 
#                               "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "IND_ANNO_TERMINO_BACHILLERATO", "PUNT_GEOGRAFIA", 
#                               "PUNT_HISTORIA", "PUNT_IDIOMA",
# ]
# df_20042 = df_20042.drop(*columnas_eliminar_df_20042)

# columnas_eliminar_df_20051 = ["DESEMP_IDIOMA", "ESTU_CARRDESEADA_COD", "ESTU_CARRDESEADA_NUCLEO", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_DEPTO_PRESENTACION", "ESTU_ETNIA", "ESTU_LIMITA_BAJAVISION", "ESTU_LIMITA_COGNITIVA", 
#                               "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", "ESTU_LIMITA_SORDOCEGUERA", "ESTU_LIMITA_SORDOINTERPRETE", 
#                               "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", "FAMI_HERMANOS_ESTUDIAN", 
#                               "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", "FAMI_NUM_HERMANOS", 
#                               "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", "FAMI_PISOSHOGAR", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "IND_COD_ICFES_TERMINO", "IND_ESTUDIO_BACHILLERATO", "IND_TERMINO_BACHILLERATO", "NOMBRE_IDIOMA", 
#                               "PUNT_GEOGRAFIA", "PUNT_HISTORIA", "PUNT_IDIOMA",
# ]
# df_20051 = df_20051.drop(*columnas_eliminar_df_20051)


# columnas_eliminar_df_20052 = ["COLE_AREA_UBICACION", "COLE_ZONA_UBICACION", "DESEMP_IDIOMA", "ESTU_CARRDESEADA_COD", "ESTU_CARRDESEADA_NUCLEO", 
#                               "ESTU_COD_MCPIO_PRESENTACION", "ESTU_DEPTO_PRESENTACION", "ESTU_ETNIA", "ESTU_LIMITA_BAJAVISION", 
#                               "ESTU_LIMITA_COGNITIVA", "ESTU_LIMITA_INVIDENTE", "ESTU_LIMITA_MOTRIZ", "ESTU_LIMITA_SORDOCEGUERA", 
#                               "ESTU_LIMITA_SORDOINTERPRETE", "ESTU_LIMITA_SORDONOINTERPRETE", "ESTU_MCPIO_PRESENTACION", 
#                               "FAMI_HERMANOS_ESTUDIAN", "FAMI_INGRESO_FMILIAR_MENSUAL", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                               "FAMI_NUM_HERMANOS", "FAMI_OCUPA_MADRE", "FAMI_OCUPA_PADRE", "FAMI_PISOSHOGAR", "IND_ANNO_TERMINO_BACHILLERATO", 
#                               "IND_COD_ICFES_TERMINO", "IND_ESTUDIO_BACHILLERATO", "NOMBRE_IDIOMA", "PUNT_GEOGRAFIA", "PUNT_HISTORIA", 
#                               "PUNT_IDIOMA",
# ]
# df_20052 = df_20052.drop(*columnas_eliminar_df_20052)

# columnas_eliminar_df_20061 = ["ESTU_CARRDESEADA_COD", "NOMBRE_IDIOMA","PUNT_IDIOMA",]
# df_20061 = df_20061.drop(*columnas_eliminar_df_20061)

# columnas_eliminar_df_20062 = ["ESTU_CARRDESEADA_COD", "NOMBRE_IDIOMA","PUNT_IDIOMA",]
# df_20061 = df_20062.drop(*columnas_eliminar_df_20062)

# columnas_eliminar_df_20072 = ["ESTU_CARRDESEADA_COD",]
# df_20071 = df_20072.drop(*columnas_eliminar_df_20072)


# columnas_eliminar_df_20081 = ["FAMI_CELULAR", "FAMI_HERMANOS_ESTUDIAN", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", 
#                              "FAMI_MOTOCICLETA", "FAMI_NUM_HERMANOS",]
# df_20081 = df_20081.drop(*columnas_eliminar_df_20081)

# columnas_eliminar_df_20082 = ["FAMI_HERMANOS_ESTUDIAN", "FAMI_LEE_ESCRIBE_MADRE", "FAMI_LEE_ESCRIBE_PADRE", "FAMI_NUM_HERMANOS",]
# df_20082 = df_20082.drop(*columnas_eliminar_df_20082)

# columnas_eliminar_df_20092 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", "DESEMP_PROFUNDIZA_CSOCIALES", 
#                               "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", "ESTU_ANOMATRICULAPRIMERO", 
#                               "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", "ESTU_ANOTERMINOBACHILLER", 
#                               "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_IESDESEADA", 
#                               "ESTU_COD_MCPIO_PRESENTACION", "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_PRESENTACION", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", 
#                               "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", 
#                               "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIO_PRESENTACION", "ESTU_MCPIO_RESIDE", "ESTU_MESTERMINOBACHILLER", 
#                               "ESTU_MOTIVO_PRESENTAVALIDACION", "ESTU_NACIONALIDAD", "ESTU_PLANTELEDUCATIVO", "ESTU_PRIVADO_LIBERTAD", 
#                               "ESTU_PROGORIENTACIONVOCACIONAL", "ESTU_PROGPORBUSCANDOCARRERA", "ESTU_PROGPORCOLOMBIAAPRENDE", 
#                               "ESTU_PROGPORINFLUENCIAALGUIEN", "ESTU_PROGPORINTERESPERSONAL", "ESTU_PROGPORMEJORARPOSICSOCIAL", 
#                               "ESTU_PROGPORTRADICIONFAMILIAR", "ESTU_RAZON_PROG_DESEADO", "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", 
#                               "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO", 
#                               "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", "ESTU_REPROBOTERCERO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", 
#                               "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", 
#                               "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "FAMI_TIENE_SERVICIOTV", "PUNT_CIENCIAS_SOCIALES", "PUNT_INTERDISC_MEDIOAMBIENTE", 
#                               "PUNT_INTERDISC_VIOLENCIAYSOC", "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", 
#                               "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA",]
# df_20092 = df_20092.drop(*columnas_eliminar_df_20092)

# columnas_eliminar_df_20101 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", "DESEMP_PROFUNDIZA_CSOCIALES", 
#                               "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", "ESTU_ANOTERMINOBACHILLER", 
#                               "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_DEPTO_PRESENTACION", "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_FECHANACIMIENTO", 
#                               "ESTU_MCPIO_PRESENTACION", "ESTU_MCPIO_RESIDE", "ESTU_MESTERMINOBACHILLER", "ESTU_MOTIVO_PRESENTAVALIDACION", 
#                               "ESTU_NACIONALIDAD", "ESTU_PRIVADO_LIBERTAD", "ESTU_TIPODOCUMENTO", "ESTU_TRABAJAACTUALMENTE", 
#                               "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", 
#                               "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", "FAMI_NIVELSISBEN", 
#                               "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", "FAMI_TELEFONO", 
#                               "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", "FAMI_TIENEINTERNET", 
#                               "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "FAMI_TIENE_SERVICIOTV", "PUNT_CIENCIAS_SOCIALES", "PUNT_INTERDISC_MEDIOAMBIENTE", 
#                               "PUNT_INTERDISC_VIOLENCIAYSOC", "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", 
#                               "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA",
# ]
# df_20101 = df_20101.drop(*columnas_eliminar_df_20101)

# columnas_eliminar_df_20102 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", "DESEMP_PROFUNDIZA_CSOCIALES", 
#                               "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", "ESTU_ANOMATRICULAPRIMERO", 
#                               "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", "ESTU_ANOTERMINOBACHILLER", 
#                               "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", 
#                               "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_PRESENTACION", "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", 
#                               "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", 
#                               "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", 
#                               "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIOIESDESEADA", "ESTU_MCPIO_PRESENTACION", "ESTU_MCPIO_RESIDE", 
#                               "ESTU_MESTERMINOBACHILLER", "ESTU_MOTIVO_PRESENTAVALIDACION", "ESTU_NACIONALIDAD", "ESTU_PRIVADO_LIBERTAD", 
#                               "ESTU_RAZONRETIROCOLEGIO", "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", "ESTU_REPROBONOVENO", 
#                               "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO", 
#                               "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", "ESTU_REPROBOTERCERO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", 
#                               "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", 
#                               "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA",
#                               "FAMI_TIENE_SERVICIOTV", "PUNT_CIENCIAS_SOCIALES", "PUNT_INTERDISC_MEDIOAMBIENTE", 
#                               "PUNT_INTERDISC_VIOLENCIAYSOC", "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", 
#                               "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA",]
# df_20102 = df_20102.drop(*columnas_eliminar_df_20102)

# columnas_eliminar_df_20111 = ["COLE_AREA_UBICACION", "COLE_CALENDARIO COLE_BILINGUE", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", 
#                               "COLE_COD_DANE_SEDE", "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO COLE_NATURALEZA", 
#                               "COLE_NOMBRE_ESTABLECIMIENTO", "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", 
#                               "DESEMP_PROFUNDIZA_CSOCIALES", "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", 
#                               "ESTU_ANOMATRICULAPRIMERO", "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", 
#                               "ESTU_ANOTERMINOBACHILLER", "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", 
#                               "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", 
#                               "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", 
#                               "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIOIESDESEADA", 
#                               "ESTU_MCPIO_RESIDE", "ESTU_MESTERMINOBACHILLER", "ESTU_MOTIVO_PRESENTAVALIDACION", "ESTU_NACIONALIDAD", 
#                               "ESTU_PAIS_RESIDE", "ESTU_PRIVADO_LIBERTAD", "ESTU_PUESTO", "ESTU_RAZONRETIROCOLEGIO", "ESTU_REPROBOCUARTO", 
#                               "ESTU_REPROBODECIMO", "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", "ESTU_REPROBOPRIMERO", 
#                               "ESTU_REPROBOQUINTO", "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", "ESTU_REPROBOTERCERO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", 
#                               "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", 
#                               "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "FAMI_TIENE_SERVICIOTV", "PERIODO ESTU_CONSECUTIVO", "PUNT_CIENCIAS_SOCIALES", "PUNT_FISICA PUNT_LENGUAJE", 
#                               "PUNT_INGLES DESEMP_INGLES", "PUNT_INTERDISC_MEDIOAMBIENTE", "PUNT_INTERDISC_VIOLENCIAYSOC", 
#                               "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA", 
#                               "PUNT_QUIMICA PUNT_BIOLOGIA",]
# df_20011 = df_20111.drop(*columnas_eliminar_df_20111)

# columnas_eliminar_df_20112 = ["COLE_AREA_UBICACION", "COLE_CALENDARIO COLE_BILINGUE", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", 
#                               "COLE_COD_DANE_SEDE", "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO COLE_NATURALEZA", 
#                               "COLE_NOMBRE_ESTABLECIMIENTO", "COLE_SEDE_PRINCIPAL", "DESEMP_INGLES", "DESEMP_PROFUNDIZA_BIOLOGIA", 
#                               "DESEMP_PROFUNDIZA_CSOCIALES", "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", 
#                               "ESTU_ANOMATRICULAPRIMERO", "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", 
#                               "ESTU_ANOTERMINOBACHILLER", "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", 
#                               "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", 
#                               "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", "ESTU_INSTPOROPORTUNIDADES", 
#                               "ESTU_INSTPOROTRARAZON", "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", "ESTU_INSTPORUNICAQUEOFRECE", 
#                               "ESTU_MCPIOIESDESEADA", "ESTU_MCPIO_RESIDE", "ESTU_MESTERMINOBACHILLER", "ESTU_MOTIVO_PRESENTAVALIDACION", 
#                               "ESTU_NACIONALIDAD", "ESTU_PAIS_RESIDE", "ESTU_PRIVADO_LIBERTAD", "ESTU_PUESTO", "ESTU_RAZONRETIROCOLEGIO", 
#                               "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", 
#                               "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO", "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", 
#                               "ESTU_REPROBOTERCERO", "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", 
#                               "ESTU_TOTALALUMNOSCURSO", "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", 
#                               "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", 
#                               "FAMI_INGRESOFMILIARMENSUAL", "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", 
#                               "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", 
#                               "FAMI_TIENEDVD", "FAMI_TIENEHORNO", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", 
#                               "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", "FAMI_TIENE_SERVICIOTV", "PERIODO ESTU_CONSECUTIVO", 
#                               "PUNT_CIENCIAS_SOCIALES", "PUNT_INTERDISC_MEDIOAMBIENTE", "PUNT_INTERDISC_VIOLENCIAYSOC", 
#                               "PUNT_MATEMATICAS PUNT_INGLES", "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", 
#                               "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA",]
# df_20112 = df_20112.drop(*columnas_eliminar_df_20112)

# columnas_eliminar_df_20121 = ["COLE_AREA_UBICACION", "COLE_CALENDARIO", "COLE_BILINGUE", "COLE_CARACTER", "COLE_COD_DANE_SEDE", 
#                               "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DEPTO_UBICACION", "COLE_GENERO", 
#                               "COLE_NATURALEZA", "COLE_JORNADA", "COLE_COD_MCPIO_UBICACION", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", "DESEMP_PROFUNDIZA_CSOCIALES", 
#                               "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", "ESTU_ANOMATRICULAPRIMERO", 
#                               "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", "ESTU_ANOTERMINOBACHILLER", 
#                               "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", 
#                               "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_COD_RESIDE_MCPIO", "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", 
#                               "ESTU_ESTUDIANTE", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", "ESTU_INSTPORAMIGOSESTUDIANDO", 
#                               "ESTU_INSTPORCOSTOMATRICULA", "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", "ESTU_INSTPORPRESTIGIO", 
#                               "ESTU_INSTPORUBICACION", "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIOIESDESEADA", "ESTU_MCPIO_RESIDE", 
#                               "ESTU_MESTERMINOBACHILLER", "ESTU_MOTIVO_PRESENTAVALIDACION", "ESTU_NACIONALIDAD", "ESTU_PAIS_RESIDE", 
#                               "ESTU_PRIVADO_LIBERTAD", "ESTU_PUESTO", "ESTU_RAZONRETIROCOLEGIO", "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", 
#                               "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO",
#                               "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", "ESTU_REPROBOTERCERO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", 
#                               "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEINTERNET", 
#                               "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "FAMI_TIENE_SERVICIOTV", "PERIODO", "ESTU_CONSECUTIVO", "PUNT_BIOLOGIA", "PUNT_FILOSOFIA", 
#                               "PUNT_CIENCIAS_SOCIALES", "PUNT_FISICA", "PUNT_QUIMICA", "PUNT_INGLES", "DESEMP_INGLES", 
#                               "PUNT_INTERDISC_MEDIOAMBIENTE", "PUNT_INTERDISC_VIOLENCIAYSOC", "PUNT_PROFUNDIZA_BIOLOGIA", 
#                               "PUNT_PROFUNDIZA_CSOCIALES", "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA", 
#                               "RECAF_PUNT_C_NATURALES", "RECAF_PUNT_INGLES", "RECAF_PUNT_LECTURA_CRITICA", "RECAF_PUNT_MATEMATICAS", 
#                               "RECAF_PUNT_SOCIALES_CIUDADANAS",]
# df_20121 = df_20121.drop(*columnas_eliminar_df_20121)

# columnas_eliminar_df_20122 = ["COLE_AREA_UBICACION", "COLE_CALENDARIO", "COLE_BILINGUE", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", 
#                               "COLE_COD_DANE_SEDE", "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", 
#                               "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", 
#                               "DESEMP_PROFUNDIZA_CSOCIALES", "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", 
#                               "ESTU_ANOMATRICULAPRIMERO", "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", 
#                               "ESTU_ANOTERMINOBACHILLER", "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", 
#                               "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_GENERO", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", 
#                               "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", 
#                               "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIOIESDESEADA", 
#                               "ESTU_MCPIO_RESIDE", "ESTU_MESTERMINOBACHILLER", "ESTU_MOTIVO_PRESENTAVALIDACION", "ESTU_NACIONALIDAD", 
#                               "ESTU_PAIS_RESIDE", "ESTU_PRIVADO_LIBERTAD", "ESTU_PUESTO", "ESTU_RAZONRETIROCOLEGIO", "ESTU_REPROBOCUARTO", 
#                               "ESTU_REPROBODECIMO", "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", "ESTU_REPROBOPRIMERO", 
#                               "ESTU_REPROBOQUINTO", "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", "ESTU_REPROBOTERCERO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", 
#                               "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", 
#                               "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "FAMI_TIENE_SERVICIOTV", "LECTURA_CRITICA", "PERIODO", "ESTU_CONSECUTIVO", "PUNT_CIENCIAS_SOCIALES", "PUNT_INGLES", 
#                               "DESEMP_INGLES", "PUNT_INTERDISC_MEDIOAMBIENTE", "PUNT_INTERDISC_VIOLENCIAYSOC", "PUNT_PROFUNDIZA_BIOLOGIA", 
#                               "PUNT_PROFUNDIZA_CSOCIALES", "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA", "RECAF_PUNT_C_NATURALES", 
#                               "RECAF_PUNT_INGLES", "RECAF_PUNT_MATEMATICAS", "RECAF_PUNT_SOCIALES_CIUDADANAS",]

# df_20122 = df_20122.drop(*columnas_eliminar_df_20122)

# columnas_eliminar_df_20131 = ["COLE_AREA_UBICACION", "COLE_JORNADA", "COLE_CALENDARIO", "COLE_BILINGUE", "COLE_CARACTER", 
#                               "COLE_COD_DANE_SEDE", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DEPTO_UBICACION", 
#                               "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_NOMBRE_SEDE", "COLE_SEDE_PRINCIPAL", "DESEMP_INGLES", "PUNT_BIOLOGIA", "DESEMP_PROFUNDIZA_BIOLOGIA", 
#                               "DESEMP_PROFUNDIZA_CSOCIALES", "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", 
#                               "ESTU_ANOMATRICULAPRIMERO", "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", 
#                               "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", 
#                               "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_PROGRAMADESEADO", 
#                               "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_EXPECTATIVAS", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", 
#                               "ESTU_INGRESAR_PROG_EDUSUPERIOR", "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", 
#                               "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", 
#                               "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIOIESDESEADA", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", 
#                               "ESTU_PAIS_RESIDE", "ESTU_PRIVADO_LIBERTAD", "ESTU_PROGORIENTACIONVOCACIONAL", "ESTU_PROGPORBUSCANDOCARRERA", 
#                               "ESTU_PROGPORCOLOMBIAAPRENDE", "ESTU_PROGPORINFLUENCIAALGUIEN", "ESTU_PROGPORINTERESPERSONAL", 
#                               "ESTU_PROGPORMEJORARPOSICSOCIAL", "ESTU_PROGPORTRADICIONFAMILIAR", "ESTU_PROGRAMADESEADO", "ESTU_PUESTO", 
#                               "ESTU_PUNT_ESPERADO_INGLES", "ESTU_PUNT_ESPERADO_LENGUAJE", "ESTU_PUNT_ESPERADO_MATEMATICAS", 
#                               "ESTU_RAZONRETIROCOLEGIO", "ESTU_RECIBESALARIO", "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", 
#                               "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO", 
#                               "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", "ESTU_REPROBOTERCERO", 
#                               "ESTU_SALARIO_ESPERADOBACHILLER", "ESTU_SALARIO_ESPERADOPROFESI", "ESTU_SALARIO_ESPERADOTECNICO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", 
#                               "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", 
#                               "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "FAMI_TIENE_SERVICIOTV", "PERIODO", "ESTU_CONSECUTIVO", "PUNT_CIENCIAS_SOCIALES", 
#                               "PUNT_INTERDISC_MEDIOAMBIENTE", "PUNT_INTERDISC_VIOLENCIAYSOC", "PUNT_MATEMATICAS", "PUNT_INGLES", 
#                               "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", "PUNT_PROFUNDIZA_LENGUAJE", 
#                               "PUNT_PROFUNDIZA_MATEMATICA", "RECAF_PUNT_C_NATURALES", "RECAF_PUNT_INGLES", "RECAF_PUNT_LECTURA_CRITICA", 
#                               "RECAF_PUNT_MATEMATICAS", "RECAF_PUNT_SOCIALES_CIUDADANAS",]
# df_20131 = df_20131.drop(*columnas_eliminar_df_20131)

# columnas_eliminar_df_20132 = ["COLE_AREA_UBICACION", "COLE_CALENDARIO", "COLE_BILINGUE", "COLE_CODIGO_ICFES", 
#                               "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", "COLE_COD_DEPTO_UBICACION", 
#                               "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_CSOCIALES", "DESEMP_PROFUNDIZA_LENGUAJE", 
#                               "DESEMP_PROFUNDIZA_MATEMATICA", "ESTU_ANOMATRICULAPRIMERO", "ESTU_ANOMATRICULASEXTO", 
#                               "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", "ESTU_ANOTER",]
# df_20132 = df_20132.drop(*columnas_eliminar_df_20132)

# columnas_eliminar_df_20141 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_GENERO", "COLE_SEDE_PRINCIPAL", "DESEMP_PROFUNDIZA_BIOLOGIA", "DESEMP_PROFUNDIZA_CSOCIALES", 
#                               "DESEMP_PROFUNDIZA_LENGUAJE", "DESEMP_PROFUNDIZA_MATEMATICA", "ESTU_ANOMATRICULAPRIMERO", "ESTU_ANOMATRICULASEXTO", 
#                               "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", "ESTU_AREARESIDE", 
#                               "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_COD_PROGRAMADESEADO", "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_CUANTOSCOLEGIOESTUDIO", 
#                               "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_PAIS_RESIDE", "ESTU_EXPECTATIVAS", 
#                               "ESTU_GENERO", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", "ESTU_INGRESAR_PROG_EDUSUPERIOR", "ESTU_INSTPORAMIGOSESTUDIANDO", 
#                               "ESTU_INSTPORCOSTOMATRICULA", "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", "ESTU_INSTPORPRESTIGIO", 
#                               "ESTU_INSTPORUBICACION", "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_MCPIOIESDESEADA", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", 
#                               "ESTU_PRIVADO_LIBERTAD", "ESTU_PROGORIENTACIONVOCACIONAL", "ESTU_PROGPORBUSCANDOCARRERA", "ESTU_PROGPORCOLOMBIAAPRENDE", 
#                               "ESTU_PROGPORINFLUENCIAALGUIEN", "ESTU_PROGPORINTERESPERSONAL", "ESTU_PROGPORMEJORARPOSICSOCIAL", 
#                               "ESTU_PROGPORTRADICIONFAMILIAR", "ESTU_PROGRAMADESEADO", "ESTU_PUESTO", "ESTU_PUNT_ESPERADO_INGLES", 
#                               "ESTU_PUNT_ESPERADO_LENGUAJE", "ESTU_PUNT_ESPERADO_MATEMATICAS", "ESTU_RAZONRETIROCOLEGIO", "ESTU_RECIBESALARIO", 
#                               "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", 
#                               "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO", "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", 
#                               "ESTU_REPROBOTERCERO", "ESTU_SALARIO_ESPERADOBACHILLER", "ESTU_SALARIO_ESPERADOPROFESI", "ESTU_SALARIO_ESPERADOTECNICO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", "ESTU_TRABAJAACTUALMENTE", 
#                               "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", 
#                               "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", "FAMI_NIVELSISBEN", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", 
#                               "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", 
#                               "FAMI_TIENEHORNO", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENE_CELULAR", 
#                               "FAMI_TIENE_NEVERA", "FAMI_TIENE_SERVICIOTV", "PERIODO", "ESTU_CONSECUTIVO", "PUNT_CIENCIAS_SOCIALES", "PUNT_FISICA", 
#                               "PUNT_QUIMICA", "PUNT_INGLES", "DESEMP_INGLES", "PUNT_INTERDISC_MEDIOAMBIENTE", "PUNT_INTERDISC_VIOLENCIAYSOC", 
#                               "PUNT_PROFUNDIZA_BIOLOGIA", "PUNT_PROFUNDIZA_CSOCIALES", "PUNT_PROFUNDIZA_LENGUAJE", "PUNT_PROFUNDIZA_MATEMATICA", 
#                               "RECAF_PUNT_C_NATURALES", "RECAF_PUNT_INGLES", "RECAF_PUNT_LECTURA_CRITICA", "RECAF_PUNT_MATEMATICAS", 
#                               "RECAF_PUNT_SOCIALES_CIUDADANAS",]
# df_20141 = df_20141.drop(*columnas_eliminar_df_20141)

# columnas_eliminar_df_20142 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DECIL_COMP_CIUDADANA", "DECIL_C_NATURALES", "DECIL_LECTURA_CRITICA", "DECIL_MATEMATICAS", 
#                               "DECIL_RAZONA_CUANTITATIVO", "DECIL_SOCIALES_CIUDADANAS", "DESEMP_INGLES", "ESTU_ANOMATRICULAPRIMERO", 
#                               "ESTU_ANOMATRICULASEXTO", "ESTU_ANOSCOLEGIOACTUAL", "ESTU_ANOSPREESCOLAR", "ESTU_ANOTERMINOQUINTO", "ESTU_ANTECEDENTES", 
#                               "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_IESDESEADA", "ESTU_COD_MCPIOIESDESEADA", 
#                               "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_PROGRAMADESEADO", "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", 
#                               "ESTU_CUANTOSCOLEGIOESTUDIO", "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", 
#                               "ESTU_EXPECTATIVAS", "ESTU_FECHANACIMIENTO", "ESTU_IESDESEADA", "ESTU_INGRESAR_PROG_EDUSUPERIOR", "ESTU_INSE_INDIVIDUAL", 
#                               "ESTU_INSTPORAMIGOSESTUDIANDO", "ESTU_INSTPORCOSTOMATRICULA", "ESTU_INSTPOROPORTUNIDADES", "ESTU_INSTPOROTRARAZON", 
#                               "ESTU_INSTPORPRESTIGIO", "ESTU_INSTPORUBICACION", "ESTU_INSTPORUNICAQUEOFRECE", "ESTU_LIMITA_AUTISMO", 
#                               "ESTU_LIMITA_CONDICIONESPECIAL", "ESTU_LIMITA_SDOWN", "ESTU_LIMITA_SORDO", "ESTU_MCPIOIESDESEADA", "ESTU_MCPIO_RESIDE", 
#                               "ESTU_NACIONALIDAD", "ESTU_NSE_INDIVIDUAL", "ESTU_PAIS_RESIDE", "ESTU_PILOPAGA", "ESTU_PRIVADO_LIBERTAD", 
#                               "ESTU_PROGORIENTACIONVOCACIONAL", "ESTU_PROGPORBUSCANDOCARRERA", "ESTU_PROGPORCOLOMBIAAPRENDE", 
#                               "ESTU_PROGPORINFLUENCIAALGUIEN", "ESTU_PROGPORINTERESPERSONAL", "ESTU_PROGPORMEJORARPOSICSOCIAL", 
#                               "ESTU_PROGPORTRADICIONFAMILIAR", "ESTU_PROGRAMADESEADO", "ESTU_PUESTO", "ESTU_PUNT_ESPERADO_INGLES", 
#                               "ESTU_PUNT_ESPERADO_LENGUAJE", "ESTU_PUNT_ESPERADO_MATEMATICAS", "ESTU_RAZONRETIROCOLEGIO", "ESTU_RECIBESALARIO", 
#                               "ESTU_REPROBOCUARTO", "ESTU_REPROBODECIMO", "ESTU_REPROBONOVENO", "ESTU_REPROBOOCTAVO", "ESTU_REPROBOONCEMAS", 
#                               "ESTU_REPROBOPRIMERO", "ESTU_REPROBOQUINTO", "ESTU_REPROBOSEGUNDO", "ESTU_REPROBOSEPTIMO", "ESTU_REPROBOSEXTO", 
#                               "ESTU_REPROBOTERCERO", "ESTU_SALARIO_ESPERADOBACHILLER", "ESTU_SALARIO_ESPERADOPROFESI", "ESTU_SALARIO_ESPERADOTECNICO", 
#                               "ESTU_SERETIROCOLEGIO", "ESTU_TIPOCARRERADESEADA", "ESTU_TIPODOCUMENTO", "ESTU_TOTALALUMNOSCURSO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", "FAMI_NIVELSISBEN", 
#                               "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", "FAMI_TELEFONO", 
#                               "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", "FAMI_TIENEINTERNET", 
#                               "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENESERVICIOTV", "FAMI_TIENE_CELULAR", "FAMI_TIENE_NEVERA", 
#                               "PERIODO", "PUNT_COMP_CIUDADANA", "PUNT_C_NATURALES", "PUNT_GLOBAL", "PUNT_INGLES", "DECIL_INGLES", 
#                               "PUNT_LECTURA_CRITICA", "PUNT_RAZONA_CUANTITATIVO", "PUNT_SOCIALES_CIUDADANAS",]
# df_20142 = df_20142.drop(*columnas_eliminar_df_20142)

# columnas_eliminar_df_20152 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DECIL_COMP_CIUDADANA", "DECIL_C_NATURALES", "DECIL_INGLES", "DECIL_LECTURA_CRITICA", 
#                               "DECIL_MATEMATICAS", "DECIL_RAZONA_CUANTITATIVO", "DECIL_SOCIALES_CIUDADANAS", "DESEMP_INGLES", "ESTU_AREARESIDE", 
#                               "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", 
#                               "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", "ESTU_FECHANACIMIENTO", 
#                               "ESTU_INSE_INDIVIDUAL", "ESTU_LIMITA_AUTISMO", "ESTU_LIMITA_CONDICIONESPECIAL", "ESTU_LIMITA_SDOWN", "ESTU_LIMITA_SORDO", 
#                               "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", "ESTU_NSE_INDIVIDUAL", "ESTU_PAIS_RESIDE", "ESTU_PILOPAGA", 
#                               "ESTU_PRIVADO_LIBERTAD", "ESTU_PUESTO", "ESTU_RECIBESALARIO", "ESTU_TIENEETNIA", "ESTU_TIPODOCUMENTO", 
#                               "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", 
#                               "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", "FAMI_NIVELSISBEN", 
#                               "FAMI_NUMHERMANOS", "FAMI_NUMLIBROS", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", 
#                               "FAMI_PISOSHOGAR", "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", 
#                               "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENESERVICIOTV", "PERIODO", 
#                               "PUNT_COMP_CIUDADANA", "PUNT_C_NATURALES", "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", 
#                               "PUNT_RAZONA_CUANTITATIVO", "PUNT_SOCIALES_CIUDADANAS",]
# df_20152 = df_20152.drop(*columnas_eliminar_df_20152)

# columnas_eliminar_df_20161 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_C_NATURALES", "DESEMP_INGLES", "DESEMP_LECTURA_CRITICA", "DESEMP_MATEMATICAS", 
#                               "DESEMP_SOCIALES_CIUDADANAS", "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", 
#                               "ESTU_ETNIA", "ESTU_FECHANACIMIENTO", "ESTU_INSE_INDIVIDUAL", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", 
#                               "ESTU_NSE_ESTABLECIMIENTO", "ESTU_NSE_INDIVIDUAL", "ESTU_PAIS_RESIDE", "ESTU_PILOPAGA", "ESTU_PRIVADO_LIBERTAD", 
#                               "ESTU_RECIBESALARIO", "ESTU_TIENEETNIA", "ESTU_TIPODOCUMENTO", "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", 
#                               "ESTU_VECESPRESENTOEXAMEN", "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", 
#                               "FAMI_INGRESOFMILIARMENSUAL", "FAMI_NIVELSISBEN", "FAMI_NUMHERMANOS", "FAMI_NUMLIBROS", "FAMI_OCUPACIONMADRE", 
#                               "FAMI_OCUPACIONPADRE", "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", 
#                               "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", "FAMI_TIENEHORNO", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", 
#                               "FAMI_TIENEMICROONDAS", "FAMI_TIENETELEVISOR", "PERCENTIL_C_NATURALES", "PERCENTIL_GLOBAL", "PERCENTIL_INGLES", 
#                               "PERCENTIL_LECTURA_CRITICA", "PERCENTIL_MATEMATICAS", "PERCENTIL_SOCIALES_CIUDADANAS", "PERIODO", "PUNT_C_NATURALES", 
#                               "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", "PUNT_SOCIALES_CIUDADANAS",]
# df_20161 = df_20161.drop(*columnas_eliminar_df_20161)

# columnas_eliminar_df_20162 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_C_NATURALES", "DESEMP_LECTURA_CRITICA", "DESEMP_MATEMATICAS", "DESEMP_SOCIALES_CIUDADANAS", 
#                               "ESTU_AREARESIDE", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_COD_RESIDE_MCPIO", "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", 
#                               "ESTU_FECHANACIMIENTO", "ESTU_INSE_INDIVIDUAL", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", "ESTU_NSE_ESTABLECIMIENTO", 
#                               "ESTU_NSE_INDIVIDUAL", "ESTU_PAIS_RESIDE", "ESTU_PILOPAGA", "ESTU_PRIVADO_LIBERTAD", "ESTU_RECIBESALARIO", 
#                               "ESTU_TIENEETNIA", "ESTU_TIPODOCUMENTO", "ESTU_TRABAJAACTUALMENTE", "ESTU_VALORPENSIONCOLEGIO", "ESTU_VECESPRESENTOEXAMEN", 
#                               "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_INGRESOFMILIARMENSUAL", 
#                               "FAMI_NIVELSISBEN", "FAMI_NUMHERMANOS", "FAMI_NUMLIBROS", "FAMI_OCUPACIONMADRE", "FAMI_OCUPACIONPADRE", 
#                               "FAMI_PERSONASHOGAR", "FAMI_PISOSHOGAR", "FAMI_TELEFONO", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENEDVD", 
#                               "FAMI_TIENEHORNO", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMICROONDAS", "FAMI_TIENESERVICIOTV", 
#                               "PERCENTIL_C_NATURALES", "PERCENTIL_GLOBAL", "PERCENTIL_INGLES", "DESEMP_INGLES", "PERCENTIL_LECTURA_CRITICA", 
#                               "PERCENTIL_MATEMATICAS", "PERCENTIL_SOCIALES_CIUDADANAS", "PERIODO", "ESTU_CONSECUTIVO", "PUNT_C_NATURALES", 
#                               "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", "PUNT_SOCIALES_CIUDADANAS",]
# df_20162 = df_20162.drop(*columnas_eliminar_df_20162)

# columnas_eliminar_df_20171 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_C_NATURALES", "DESEMP_INGLES", "DESEMP_LECTURA_CRITICA", "DESEMP_MATEMATICAS", 
#                               "DESEMP_SOCIALES_CIUDADANAS", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_COD_RESIDE_MCPIO", "ESTU_DEDICACIONINTERNET", "ESTU_DEDICACIONLECTURADIARIA", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", "ESTU_FECHANACIMIENTO", "ESTU_HORASSEMANATRABAJA",
#                                 "ESTU_INSE_INDIVIDUAL", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", "ESTU_NSE_ESTABLECIMIENTO", "ESTU_NSE_INDIVIDUAL", 
#                                 "ESTU_PAIS_RESIDE", "ESTU_PRIVADO_LIBERTAD", "ESTU_TIENEETNIA", "ESTU_TIPODOCUMENTO", "ESTU_TIPOREMUNERACION", 
#                                 "FAMI_COMECARNEPESCADOHUEVO", "FAMI_COMECEREALFRUTOSLEGUMBRE", "FAMI_COMELECHEDERIVADOS", "FAMI_CUARTOSHOGAR", 
#                                 "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_NUMLIBROS", "FAMI_PERSONASHOGAR", 
#                                 "FAMI_SITUACIONECONOMICA", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", "FAMI_TIENECONSOLAVIDEOJUEGOS", 
#                                 "FAMI_TIENEHORNOMICROOGAS", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", "FAMI_TIENEMOTOCICLETA", "FAMI_TIENESERVICIOTV", 
#                                 "FAMI_TRABAJOLABORMADRE", "FAMI_TRABAJOLABORPADRE", "PERCENTIL_C_NATURALES", "PERCENTIL_GLOBAL", "PERCENTIL_INGLES", 
#                                 "PERCENTIL_LECTURA_CRITICA", "PERCENTIL_MATEMATICAS", "PERCENTIL_SOCIALES_CIUDADANAS", "PERIODO", "PUNT_C_NATURALES", 
#                                 "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", "PUNT_SOCIALES_CIUDADANAS",]
# df_20171 = df_20171.drop(*columnas_eliminar_df_20171)

# columnas_eliminar_df_20172 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_C_NATURALES", "DESEMP_INGLES", "DESEMP_LECTURA_CRITICA", "DESEMP_MATEMATICAS", 
#                               "DESEMP_SOCIALES_CIUDADANAS", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_COD_RESIDE_MCPIO", "ESTU_DEDICACIONINTERNET", "ESTU_DEDICACIONLECTURADIARIA", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", "ESTU_FECHANACIMIENTO", "ESTU_HORASSEMANATRABAJA", 
#                               "ESTU_INSE_INDIVIDUAL", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", "ESTU_NSE_ESTABLECIMIENTO", "ESTU_NSE_INDIVIDUAL", 
#                               "ESTU_PAIS_RESIDE", "ESTU_PILOPAGA", "ESTU_PRIVADO_LIBERTAD", "ESTU_TIENEETNIA", "ESTU_TIPODOCUMENTO", 
#                               "ESTU_TIPOREMUNERACION", "FAMI_COMECARNEPESCADOHUEVO", "FAMI_COMECEREALFRUTOSLEGUMBRE", "FAMI_COMELECHEDERIVADOS", 
#                               "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_NUMLIBROS", 
#                               "FAMI_PERSONASHOGAR", "FAMI_SITUACIONECONOMICA", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", 
#                               "FAMI_TIENECONSOLAVIDEOJUEGOS", "FAMI_TIENEHORNOMICROOGAS", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", 
#                               "FAMI_TIENEMOTOCICLETA", "FAMI_TIENESERVICIOTV", "FAMI_TRABAJOLABORMADRE", "FAMI_TRABAJOLABORPADRE", 
#                               "PERCENTIL_C_NATURALES", "PERCENTIL_GLOBAL", "PERCENTIL_INGLES", "PERCENTIL_LECTURA_CRITICA", "PERCENTIL_MATEMATICAS", 
#                               "PERCENTIL_SOCIALES_CIUDADANAS", "PERIODO", "PUNT_C_NATURALES", "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", 
#                               "PUNT_SOCIALES_CIUDADANAS",]
# df_20172 = df_20172.drop(*columnas_eliminar_df_20172)

# columnas_eliminar_df_20181 = ["COLE_AREA_UBICACION", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", 
#                               "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", "COLE_NOMBRE_ESTABLECIMIENTO", 
#                               "COLE_SEDE_PRINCIPAL", "DESEMP_C_NATURALES", "DESEMP_INGLES", "DESEMP_LECTURA_CRITICA", "DESEMP_MATEMATICAS", 
#                               "DESEMP_SOCIALES_CIUDADANAS", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_COD_RESIDE_DEPTO", 
#                               "ESTU_COD_RESIDE_MCPIO", "ESTU_DEDICACIONINTERNET", "ESTU_DEDICACIONLECTURADIARIA", "ESTU_DEPTO_RESIDE", 
#                               "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", "ESTU_FECHANACIMIENTO", "ESTU_HORASSEMANATRABAJA", 
#                               "ESTU_INSE_INDIVIDUAL", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", "ESTU_NSE_ESTABLECIMIENTO", "ESTU_NSE_INDIVIDUAL", 
#                               "ESTU_PAIS_RESIDE", "ESTU_PILOPAGA", "ESTU_PRIVADO_LIBERTAD", "ESTU_TIENEETNIA", "ESTU_TIPODOCUMENTO", 
#                               "ESTU_TIPOREMUNERACION", "FAMI_COMECARNEPESCADOHUEVO", "FAMI_COMECEREALFRUTOSLEGUMBRE", "FAMI_COMELECHEDERIVADOS", 
#                               "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", "FAMI_NUMLIBROS", 
#                               "FAMI_PERSONASHOGAR", "FAMI_SITUACIONECONOMICA", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", 
#                               "FAMI_TIENECONSOLAVIDEOJUEGOS", "FAMI_TIENEHORNOMICROOGAS", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", 
#                               "FAMI_TIENEMOTOCICLETA", "FAMI_TIENESERVICIOTV", "FAMI_TRABAJOLABORMADRE", "FAMI_TRABAJOLABORPADRE", 
#                               "PERCENTIL_C_NATURALES", "PERCENTIL_GLOBAL", "PERCENTIL_INGLES", "PERCENTIL_LECTURA_CRITICA", "PERCENTIL_MATEMATICAS", 
#                               "PERCENTIL_SOCIALES_CIUDADANAS", "PERIODO", "PUNT_C_NATURALES", "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", 
#                               "PUNT_SOCIALES_CIUDADANAS",]
# df_20181 = df_20181.drop(*columnas_eliminar_df_20181)

# columnas_eliminar_df_20182 = ["COLE_AREA_UBICACION", "COLE_CALENDARIO", "COLE_BILINGUE", "COLE_CODIGO_ICFES", "COLE_COD_DANE_ESTABLECIMIENTO", 
#                               "COLE_COD_DANE_SEDE", "COLE_COD_DEPTO_UBICACION", "COLE_COD_MCPIO_UBICACION", "COLE_GENERO", "COLE_NATURALEZA", 
#                               "COLE_NOMBRE_ESTABLECIMIENTO", "COLE_SEDE_PRINCIPAL", "DESEMP_C_NATURALES", "DESEMP_INGLES", "DESEMP_LECTURA_CRITICA", 
#                               "DESEMP_MATEMATICAS", "DESEMP_SOCIALES_CIUDADANAS", "ESTU_COD_DEPTO_PRESENTACION", "ESTU_COD_MCPIO_PRESENTACION", 
#                               "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "ESTU_DEDICACIONINTERNET", "ESTU_DEDICACIONLECTURADIARIA", 
#                               "ESTU_DEPTO_RESIDE", "ESTU_ESTADOINVESTIGACION", "ESTU_ESTUDIANTE", "ESTU_ETNIA", "ESTU_FECHANACIMIENTO", 
#                               "ESTU_GENERACION-E", "ESTU_HORASSEMANATRABAJA", "ESTU_INSE_INDIVIDUAL", "ESTU_MCPIO_RESIDE", "ESTU_NACIONALIDAD", 
#                               "ESTU_NSE_ESTABLECIMIENTO", "ESTU_NSE_INDIVIDUAL", "ESTU_PAIS_RESIDE", "ESTU_PRIVADO_LIBERTAD", "ESTU_TIENEETNIA", 
#                               "ESTU_TIPODOCUMENTO", "ESTU_TIPOREMUNERACION", "FAMI_COMECARNEPESCADOHUEVO", "FAMI_COMECEREALFRUTOSLEGUMBRE", 
#                               "FAMI_COMELECHEDERIVADOS", "FAMI_CUARTOSHOGAR", "FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA", 
#                               "FAMI_NUMLIBROS", "FAMI_PERSONASHOGAR", "FAMI_SITUACIONECONOMICA", "FAMI_TIENEAUTOMOVIL", "FAMI_TIENECOMPUTADOR", 
#                               "FAMI_TIENECONSOLAVIDEOJUEGOS", "FAMI_TIENEHORNOMICROOGAS", "FAMI_TIENEINTERNET", "FAMI_TIENELAVADORA", 
#                               "FAMI_TIENEMOTOCICLETA", "FAMI_TIENESERVICIOTV", "FAMI_TRABAJOLABORMADRE", "FAMI_TRABAJOLABORPADRE", 
#                               "PERCENTIL_C_NATURALES", "PERCENTIL_GLOBAL", "PERCENTIL_INGLES", "PERCENTIL_LECTURA_CRITICA", "PERCENTIL_MATEMATICAS", 
#                               "PERCENTIL_SOCIALES_CIUDADANAS", "PERIODO", "PUNT_C_NATURALES", "PUNT_GLOBAL", "PUNT_INGLES", "PUNT_LECTURA_CRITICA", 
#                               "PUNT_SOCIALES_CIUDADANAS",]
# df_20182 = df_20182.drop(*columnas_eliminar_df_20182)

# columnas_eliminar_df_20191_ = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_GENERACIONE","ESTU_HORASSEMANATRABAJA",
#                               "ESTU_INSE_INDIVIDUAL","ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE",
#                               "ESTU_PRIVADO_LIBERTAD","ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE",
#                               "FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS",
#                               "FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS",
#                               "FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV",
#                               "FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES","PERCENTIL_GLOBAL","PERCENTIL_INGLES",
#                               "PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS","PERIODO","PUNT_C_NATURALES",
#                               "PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20191_ = df_20191_.drop(*columnas_eliminar_df_20191_)

# columnas_eliminar_df_20192 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_ETNIA","ESTU_FECHANACIMIENTO","ESTU_GENERACIONE",
#                               "ESTU_HORASSEMANATRABAJA","ESTU_INSE_INDIVIDUAL","ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO",
#                               "ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE","ESTU_PRIVADO_LIBERTAD","ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION",
#                               "FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE","FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE",
#                               "FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS","FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL",
#                               "FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS","FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA",
#                               "FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES",
#                               "PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS",
#                               "PERIODO","ESTU_CONSECUTIVO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20192 = df_20192.drop(*columnas_eliminar_df_20192)

# columnas_eliminar_df_20201 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION","ESTU_COD_MCPIO_PRESENTACION",
#                               "ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA","ESTU_DEPTO_RESIDE",
#                               "ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_GENERACIONE","ESTU_HORASSEMANATRABAJA","ESTU_INSE_INDIVIDUAL",
#                               "ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE","ESTU_PRIVADO_LIBERTAD",
#                               "ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE",
#                               "FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS",
#                               "FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS",
#                               "FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE",
#                               "FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS",
#                               "PERCENTIL_SOCIALES_CIUDADANAS","PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA",
#                               "PUNT_SOCIALES_CIUDADANAS",]
# df_20201 = df_20201.drop(*columnas_eliminar_df_20201)

# columnas_eliminar_df_20202 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_GENERACION-E","ESTU_HORASSEMANATRABAJA",
#                               "ESTU_INSE_INDIVIDUAL","ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE",
#                               "ESTU_PRIVADO_LIBERTAD","ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE",
#                               "FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS",
#                               "FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS",
#                               "FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV",
#                               "FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA",
#                               "PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS","PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES",
#                               "PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20202 = df_20202.drop(*columnas_eliminar_df_20202)

# columnas_eliminar_df_20211 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_HORASSEMANATRABAJA","ESTU_MCPIO_RESIDE",
#                               "ESTU_NACIONALIDAD","ESTU_PAIS_RESIDE","ESTU_PRIVADO_LIBERTAD","ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION",
#                               "FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE","FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE",
#                               "FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS","FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL",
#                               "FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS","FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA",
#                               "FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES",
#                               "PERCENTIL_ESPECIAL_GLOBAL","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS",
#                               "PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20211 = df_20211.drop(*columnas_eliminar_df_20211)

# columnas_eliminar_df_20212 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_GENERACION-E","ESTU_HORASSEMANATRABAJA",
#                               "ESTU_INSE_INDIVIDUAL","ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE",
#                               "ESTU_PRIVADO_LIBERTAD","ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO",
#                               "FAMI_COMECEREALFRUTOSLEGUMBRE","FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE",
#                               "FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS","FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR",
#                               "FAMI_TIENECONSOLAVIDEOJUEGOS","FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA",
#                               "FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES","PERCENTIL_ESPECIAL_GLOBAL",
#                               "PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS",
#                               "PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20212 = df_20212.drop(*columnas_eliminar_df_20212)

# columnas_eliminar_df_20221 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_AGREGADO","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_HORASSEMANATRABAJA","ESTU_INSE_INDIVIDUAL",
#                               "ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE","ESTU_PRIVADO_LIBERTAD",
#                               "ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE",
#                               "FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS",
#                               "FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS",
#                               "FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE",
#                               "FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES","PERCENTIL_ESPECIAL_GLOBAL","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA",
#                               "PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS","PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA",
#                               "PUNT_SOCIALES_CIUDADANAS",]
# df_20221 = df_20221.drop(*columnas_eliminar_df_20221)

# columnas_eliminar_df_20222 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_HORASSEMANATRABAJA","ESTU_INSE_INDIVIDUAL",
#                               "ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE","ESTU_PRIVADO_LIBERTAD",
#                               "ESTU_TIENEETNIA","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE",
#                               "FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS",
#                               "FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS","FAMI_TIENEHORNOMICROOGAS",
#                               "FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE",
#                               "PERCENTIL_C_NATURALES","PERCENTIL_ESPECIAL_GLOBAL","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS",
#                               "PERCENTIL_SOCIALES_CIUDADANAS","PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20222 = df_20222.drop(*columnas_eliminar_df_20222)

# columnas_eliminar_df_20231 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_HORASSEMANATRABAJA","ESTU_INSE_INDIVIDUAL",
#                               "ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL","ESTU_PAIS_RESIDE","ESTU_PRESENTACIONSABADO",
#                               "ESTU_PRIVADO_LIBERTAD","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION","FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE",
#                               "FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE","FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS",
#                               "FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL","FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS",
#                               "FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA","FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE",
#                               "FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES","PERCENTIL_ESPECIAL_GLOBAL","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA",
#                               "PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS","PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA",
#                               "PUNT_SOCIALES_CIUDADANAS","SEED_CODIGOMEN","SEED_NOMBRE",]
# df_20231 = df_20231.drop(*columnas_eliminar_df_20231)

# columnas_eliminar_df_20232 = ["COLE_AREA_UBICACION","COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO","COLE_COD_DANE_SEDE","COLE_COD_DEPTO_UBICACION",
#                               "COLE_COD_MCPIO_UBICACION","COLE_GENERO","COLE_NATURALEZA","COLE_NOMBRE_ESTABLECIMIENTO","COLE_SEDE_PRINCIPAL","DESEMP_C_NATURALES",
#                               "DESEMP_INGLES","DESEMP_LECTURA_CRITICA","DESEMP_MATEMATICAS","DESEMP_SOCIALES_CIUDADANAS","ESTU_COD_DEPTO_PRESENTACION",
#                               "ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_RESIDE_DEPTO","ESTU_COD_RESIDE_MCPIO","ESTU_DEDICACIONINTERNET","ESTU_DEDICACIONLECTURADIARIA",
#                               "ESTU_DEPTO_RESIDE","ESTU_ESTADOINVESTIGACION","ESTU_ESTUDIANTE","ESTU_FECHANACIMIENTO","ESTU_GENERACION","ESTU_HORASSEMANATRABAJA",
#                               "ESTU_INSE_INDIVIDUAL","ESTU_LENGUANATIVA","ESTU_MCPIO_RESIDE","ESTU_NACIONALIDAD","ESTU_NSE_ESTABLECIMIENTO","ESTU_NSE_INDIVIDUAL",
#                               "ESTU_PAIS_RESIDE","ESTU_PRESENTACIONSABADO","ESTU_PRIVADO_LIBERTAD","ESTU_TIPODOCUMENTO","ESTU_TIPOREMUNERACION",
#                               "FAMI_COMECARNEPESCADOHUEVO","FAMI_COMECEREALFRUTOSLEGUMBRE","FAMI_COMELECHEDERIVADOS","FAMI_CUARTOSHOGAR","FAMI_EDUCACIONMADRE",
#                               "FAMI_EDUCACIONPADRE","FAMI_ESTRATOVIVIENDA","FAMI_NUMLIBROS","FAMI_PERSONASHOGAR","FAMI_SITUACIONECONOMICA","FAMI_TIENEAUTOMOVIL",
#                               "FAMI_TIENECOMPUTADOR","FAMI_TIENECONSOLAVIDEOJUEGOS","FAMI_TIENEHORNOMICROOGAS","FAMI_TIENEINTERNET","FAMI_TIENELAVADORA",
#                               "FAMI_TIENEMOTOCICLETA","FAMI_TIENESERVICIOTV","FAMI_TRABAJOLABORMADRE","FAMI_TRABAJOLABORPADRE","PERCENTIL_C_NATURALES",
#                               "PERCENTIL_ESPECIAL_GLOBAL","PERCENTIL_GLOBAL","PERCENTIL_INGLES","PERCENTIL_LECTURA_CRITICA","PERCENTIL_MATEMATICAS","PERCENTIL_SOCIALES_CIUDADANAS",
#                               "PERIODO","PUNT_C_NATURALES","PUNT_GLOBAL","PUNT_INGLES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS",]
# df_20232 = df_20232.drop(*columnas_eliminar_df_20232)

# %%
# from functools import reduce

# # Colocar los nombres de todas las tablas
# lista_df = [df_20001, df_20002, df_20011, df_20012, df_20021, df_20022, df_20032, df_20041, df_20042, df_20051, df_20052, df_20061, df_20062, df_20071, df_20072, df_20081, df_20082, df_20091, df_20092, df_20101, df_20102, df_20111, df_20112, df_20122, df_20151, df_20152, df_20191_, df_20201, df_20202, df_20211, df_20212,]

# df_union_total = reduce(lambda df_a, df_b: df_a.unionByName(df_b, allowMissingColumns=True), lista_df)

# df_union_total.show(10)
# Out:
# +----------------+--------------+--------------------+------------+------------------+-----------+-------------------+-------------------+--------------------+-------------+----------------+--------------+-----------+------------+-------------+---------------------+--------------------+-------------------+----------------------+-------------------+----------------+----------------+------------+---------------+-------------+-------------------+-------------------+-----------------+-----------------+-----------------------------+-----------------------+-----------------------+----------+---------------------+---------------------------+-----------------------------+------------------+-------------+--------------+--------------------+----------+-----------+--------------------+--------------------+-------------------+---------------+----------------------------+----------------------+----------------------+----------------+----------------+-----------------+-----------------------------
# ...

# %%
# DEBO DE LEER EL ARCHIVO FINAL EN UN FORMATO PARQUET, PARA LEER Y TRABAJAR SOBRE EL.
# Descargar un solo formato parquet.
# num_filas = df_union_total.count()
# num_columnas = len(df_union_total.columns)
# print(f"Filas: {num_filas}, Columnas: {num_columnas}")
# Out:
# Filas: 8536271, Columnas: 245

# %%
print("lista_columnas_df_20001 = ",df_20001.columns, "\n\n")
print("lista_columnas_df_20002 = ",df_20002.columns, "\n\n")
print("lista_columnas_df_20011 = ",df_20011.columns, "\n\n")
print("lista_columnas_df_20012 = ",df_20012.columns, "\n\n")
print("lista_columnas_df_20021 = ",df_20021.columns, "\n\n")
print("lista_columnas_df_20022 = ",df_20022.columns, "\n\n")
print("lista_columnas_df_20032 = ",df_20032.columns, "\n\n")
print("lista_columnas_df_20041 = ",df_20041.columns, "\n\n")
print("lista_columnas_df_20042 = ",df_20042.columns, "\n\n")
print("lista_columnas_df_20051 = ",df_20051.columns, "\n\n")
print("lista_columnas_df_20052 = ",df_20052.columns, "\n\n")
print("lista_columnas_df_20061 = ",df_20061.columns, "\n\n")
print("lista_columnas_df_20062 = ",df_20062.columns, "\n\n")
print("lista_columnas_df_20071 = ",df_20071.columns, "\n\n")
print("lista_columnas_df_20072 = ",df_20072.columns, "\n\n")
print("lista_columnas_df_20081 = ",df_20081.columns, "\n\n")
print("lista_columnas_df_20082 = ",df_20082.columns, "\n\n")
print("lista_columnas_df_20091 = ",df_20091.columns, "\n\n")
print("lista_columnas_df_20092 = ",df_20092.columns, "\n\n")
print("lista_columnas_df_20101 = ",df_20101.columns, "\n\n")
print("lista_columnas_df_20102 = ",df_20102.columns, "\n\n")
print("lista_columnas_df_20111 = ",df_20111.columns, "\n\n")
print("lista_columnas_df_20112 = ",df_20112.columns, "\n\n")
print("lista_columnas_df_20121 = ",df_20121.columns, "\n\n")
print("lista_columnas_df_20122 = ",df_20122.columns, "\n\n")
print("lista_columnas_df_20131 = ",df_20131.columns, "\n\n")
print("lista_columnas_df_20132 = ",df_20132.columns, "\n\n")
print("lista_columnas_df_20141 = ",df_20141.columns, "\n\n")
print("lista_columnas_df_20142 = ",df_20142.columns, "\n\n")
print("lista_columnas_df_20151 = ",df_20151.columns, "\n\n")
print("lista_columnas_df_20152 = ",df_20152.columns, "\n\n")
print("lista_columnas_df_20161 = ",df_20161.columns, "\n\n")
print("lista_columnas_df_20162 = ",df_20162.columns, "\n\n")
print("lista_columnas_df_20171 = ",df_20171.columns, "\n\n")
print("lista_columnas_df_20172 = ",df_20172.columns, "\n\n")
print("lista_columnas_df_20181 = ",df_20181.columns, "\n\n")
print("lista_columnas_df_20182 = ",df_20182.columns, "\n\n")
print("lista_columnas_df_20192 = ",df_20192.columns, "\n\n")
print("lista_columnas_df_20191_ = ",df_20191_.columns, "\n\n")
print("lista_columnas_df_20201 = ",df_20201.columns, "\n\n")
print("lista_columnas_df_20202 = ",df_20202.columns, "\n\n")
print("lista_columnas_df_20211 = ",df_20211.columns, "\n\n")
print("lista_columnas_df_20212 = ",df_20212.columns, "\n\n")
print("lista_columnas_df_20221 = ",df_20221.columns, "\n\n")
print("lista_columnas_df_20222 = ",df_20222.columns, "\n\n")
print("lista_columnas_df_20231 = ",df_20231.columns, "\n\n")
print("lista_columnas_df_20232 = ",df_20232.columns, "\n\n")
# Out:
# lista_columnas_df_20001 =  ['ESTU_CONSECUTIVO', 'COLE_COD_ICFES', 'COLE_NOMBRE_SEDE', 'IND_ANNO_TERMINO_BACHILLERATO', 'COLE_JORNADA', 'COLE_VALOR_PENSION', 'ESTU_GENERO', 'ESTU_NACIMIENTO_DIA', 'ESTU_NACIMIENTO_MES', 'ESTU_NACIMIENTO_ANNO', 'ESTU_DEPTO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION', 'ESTU_LIMITA_INVIDENTE', 'ESTU_LIMITA_SORDOINTERPRETE', 'ESTU_LIMITA_SORDONOINTERPRETE', 'ESTU_LIMITA_MOTRIZ', 'PUNT_BIOLOGIA', 'PUNT_MATEMATICAS', 'PUNT_FILOSOFIA', 'PUNT_FISICA', 'PUNT_HISTORIA', 'PUNT_QUIMICA', 'PUNT_LENGUAJE', 'PUNT_GEOGRAFIA', 'COD_INTERDISCIPLINAR', 'PUNT_INTERDISCIPLINAR', 'COD_IDIOMA', 'PUNT_IDIOMA', 'ESTU_IES_COD_DESEADA', 'ESTU_RAZONINSTITUTO', 'ESTU_CARRDESEADA_COD', 'ESTU_CARRDESEADA_RAZON', 'FAMI_PERSONAS_HOGAR', 'FAMI_VIVIENDA_PROPIA', 'FAMI_DEUDA_VIVIENDA', 'FAMI_APORTANTES', 'FAMI_INGRESO_FMILIAR_MENSUAL', 'FAMI_LEE_ESCRIBE_PADRE', 'FAMI_LEE_ESCRIBE_MADRE', 'FAMI_EDUCA_PADRE', 'FAMI_EDUCA_MADRE', 'FAMI_OCUPA_PADRE', 'FAMI_OCUPA_MADRE', 'FAMI_NUM_HERMANOS', 'FAM
# ...

# %%
todas_las_listas = [
    list(df_20001.columns),
    list(df_20002.columns),
    list(df_20011.columns),
    list(df_20012.columns),
    list(df_20021.columns),
    list(df_20022.columns),
    list(df_20032.columns),
    list(df_20041.columns),
    list(df_20042.columns),
    list(df_20051.columns),
    list(df_20052.columns),
    list(df_20061.columns),
    list(df_20062.columns),
    list(df_20071.columns),
    list(df_20072.columns),
    list(df_20081.columns),
    list(df_20082.columns),
    list(df_20091.columns),
    list(df_20092.columns),
    list(df_20101.columns),
    list(df_20102.columns),
    list(df_20111.columns),
    list(df_20112.columns),
    list(df_20121.columns),
    list(df_20122.columns),
    list(df_20131.columns),
    list(df_20132.columns),
    list(df_20141.columns),
    list(df_20142.columns),
    list(df_20151.columns),
    list(df_20152.columns),
    list(df_20161.columns),
    list(df_20162.columns),
    list(df_20171.columns),
    list(df_20172.columns),
    list(df_20181.columns),
    list(df_20182.columns),
    list(df_20192.columns),
    list(df_20191_.columns),
    list(df_20201.columns),
    list(df_20202.columns),
    list(df_20211.columns),
    list(df_20212.columns),
    list(df_20221.columns),
    list(df_20222.columns),
    list(df_20231.columns),
    list(df_20232.columns),
]

# Paso 2: Intersección de todas las listas
from functools import reduce

# Convertimos todas las listas en sets y aplicamos intersección
elementos_comunes = list(reduce(lambda x, y: set(x) & set(y), todas_las_listas))

# Resultado
print("Elementos comunes a todas las listas:")
print(elementos_comunes)
# Out:
# Elementos comunes a todas las listas:
# ['ESTU_GENERO', 'ESTU_CONSECUTIVO', 'COLE_CALENDARIO', 'COLE_NOMBRE_SEDE', 'PUNT_MATEMATICAS', 'COLE_CARACTER', 'COLE_JORNADA', 'COLE_BILINGUE']

# %%
# import glob

# lista_archivos = glob.glob("BASES_ED/SABER11ENUNA/*.txt")

# # dataframes = []

# for nombre_archivo in lista_archivos:

#     with open(nombre_archivo, "r", encoding="latin-1") as file:
#         primera_linea = file.readline()

#         if "|" in primera_linea :
#             print(nombre_archivo, "con |")
#             # df = spark.read.csv(nombre_archivo, header=True, inferSchema=True, sep="|")

#         elif "¬" in primera_linea:
#             print(nombre_archivo, "con ¬")
#             # df = spark.read.csv(nombre_archivo, header=True, inferSchema=True, sep="¬")
        
#         # dataframes.append(df)

# print("Cantidad de tablas", len(dataframes))
# Out:
# BASES_ED/SABER11ENUNA/SB11_20001.txt con |
# BASES_ED/SABER11ENUNA/SB11_20002.txt con |
# BASES_ED/SABER11ENUNA/SB11_20011.txt con |
# BASES_ED/SABER11ENUNA/SB11_20012.txt con |
# BASES_ED/SABER11ENUNA/SB11_20021.txt con |
# BASES_ED/SABER11ENUNA/SB11_20022.txt con |
# BASES_ED/SABER11ENUNA/SB11_20032.txt con |
# BASES_ED/SABER11ENUNA/SB11_20041.txt con |
# BASES_ED/SABER11ENUNA/SB11_20042.txt con |
# BASES_ED/SABER11ENUNA/SB11_20051.txt con |
# BASES_ED/SABER11ENUNA/SB11_20052.txt con |
# BASES_ED/SABER11ENUNA/SB11_20061.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20062.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20071.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20072.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20081.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20082.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20091.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20092.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20101.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20102.txt con ¬
# BASES_ED/SABER11ENUNA/SB11_20111.txt con ¬
# ...
